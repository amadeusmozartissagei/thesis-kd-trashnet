# %%
#!/usr/bin/env python3
"""
Kaggle-ready Focus-RCNet baseline CE experiment.

This script isolates the protocol change requested for the replication:
    - epochs: 200 instead of 100
    - batch size: 16 instead of 8

The dataset, seed, augmentation, architecture, input size, optimizer, and
loss match Results/notebook2-phase1-focus-rcnet.ipynb. Knowledge distillation
is intentionally disabled.

Expected Kaggle inputs:
    Dataset:
        /kaggle/input/datasets/feyzazkefe/trashnet/dataset-resized

    Optional teacher checkpoint used only to reuse the exact split indices:
        /kaggle/input/notebooks/hamzapratama/notebook1-teacher-training/
        efficientnet_b4_teacher_best.pth

If the teacher checkpoint is not attached, the script recreates the same
stratified 70/30 split with seed 42.
"""

import copy
import csv
import os
import random
import time
from collections import Counter
from pathlib import Path

import albumentations as A
import matplotlib
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from albumentations.pytorch import ToTensorV2
from sklearn.model_selection import train_test_split
from torch.cuda.amp import GradScaler, autocast
from torch.utils.data import DataLoader, Subset
from torchvision import datasets

matplotlib.use("Agg")
import matplotlib.pyplot as plt


class Config:
    EXPERIMENT_NAME = "Focus-RCNet Baseline CE - 200 Epochs, Batch Size 16"
    EXPERIMENT_ID = "focus-rcnet-baseline-ce-e200-bs16"

    SEED = 42
    DATASET_NAME = "TrashNet"
    NUM_CLASSES = 6
    CLASS_NAMES = ["cardboard", "glass", "metal", "paper", "plastic", "trash"]
    TRAIN_SPLIT = 0.7
    VAL_SPLIT = 0.3

    IMG_SIZE = 380
    EPOCHS = 200
    BATCH_SIZE = 16

    OPTIMIZER = "SGD"
    LR = 0.05
    MOMENTUM = 0.9
    WEIGHT_DECAY = 1e-4
    SCHEDULER = "CosineAnnealingLR"
    T_MAX = EPOCHS
    USE_AMP = True

    DATASET_PATH = "/kaggle/input/datasets/feyzazkefe/trashnet/dataset-resized"
    TEACHER_CHECKPOINT_PATH = (
        "/kaggle/input/notebooks/hamzapratama/notebook1-teacher-training/"
        "efficientnet_b4_teacher_best.pth"
    )
    OUTPUT_DIR = "/kaggle/working"

    CHECKPOINT_FILENAME = "focus_rcnet_baseline_ce_e200_bs16_best.pth"
    HISTORY_FILENAME = "training_history_focus_rcnet_baseline_ce_e200_bs16.csv"
    SUMMARY_FILENAME = "summary_focus_rcnet_baseline_ce_e200_bs16.csv"
    CURVES_FILENAME = "training_curves_focus_rcnet_baseline_ce_e200_bs16.png"

    ORIGINAL_LOCAL_BASELINE_ACC = 0.8524
    PAPER_FOCUS_RCNET_ACC = 0.9000


cfg = Config()


def seed_everything(seed: int) -> None:
    """Set random seeds using the same deterministic protocol as Notebook 2."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ["PYTHONHASHSEED"] = str(seed)


class AlbumentationsDataset(torch.utils.data.Dataset):
    """Wrap an ImageFolder-compatible dataset with Albumentations transforms."""

    def __init__(self, dataset, transform=None):
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        image = np.array(image)
        if self.transform:
            image = self.transform(image=image)["image"]
        return image, label


class Focus(nn.Module):
    """YOLOv5-style Focus module: spatial slicing followed by CBS."""

    def __init__(self, in_channels: int, out_channels: int, kernel_size: int = 3):
        super().__init__()
        padding = kernel_size // 2
        self.conv = nn.Sequential(
            nn.Conv2d(
                in_channels * 4,
                out_channels,
                kernel_size,
                stride=1,
                padding=padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.SiLU(inplace=True),
        )

    def forward(self, x):
        x = torch.cat(
            [
                x[..., ::2, ::2],
                x[..., 1::2, ::2],
                x[..., ::2, 1::2],
                x[..., 1::2, 1::2],
            ],
            dim=1,
        )
        return self.conv(x)


class SimAM(nn.Module):
    """Parameter-free SimAM attention."""

    def __init__(self, e_lambda: float = 1e-4):
        super().__init__()
        self.e_lambda = e_lambda

    def forward(self, x):
        _, _, height, width = x.size()
        n = height * width - 1
        x_minus_mu_sq = (x - x.mean(dim=[2, 3], keepdim=True)).pow(2)
        y = (
            x_minus_mu_sq
            / (
                4
                * (
                    x_minus_mu_sq.sum(dim=[2, 3], keepdim=True) / n
                    + self.e_lambda
                )
            )
            + 0.5
        )
        return x * torch.sigmoid(y)


class SandglassBlock(nn.Module):
    """MobileNeXt-style sandglass block used by the replication notebook."""

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        stride: int = 1,
        reduction: int = 2,
    ):
        super().__init__()
        self.use_residual = stride == 1 and in_channels == out_channels
        mid_channels = max(in_channels // reduction, 1)
        self.layers = nn.Sequential(
            nn.Conv2d(
                in_channels,
                in_channels,
                3,
                stride=stride,
                padding=1,
                groups=in_channels,
                bias=False,
            ),
            nn.BatchNorm2d(in_channels),
            nn.SiLU(inplace=True),
            nn.Conv2d(in_channels, mid_channels, 1, bias=False),
            nn.BatchNorm2d(mid_channels),
            nn.Conv2d(mid_channels, out_channels, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.SiLU(inplace=True),
            nn.Conv2d(
                out_channels,
                out_channels,
                3,
                stride=1,
                padding=1,
                groups=out_channels,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
        )

    def forward(self, x):
        output = self.layers(x)
        return x + output if self.use_residual else output


class FocusRCNet(nn.Module):
    """Focus-RCNet architecture copied from Notebook 2."""

    STAGE_CONFIG = [
        (48, 4, 2, 2),
        (96, 3, 2, 2),
        (192, 2, 2, 2),
        (384, 2, 2, 2),
    ]

    def __init__(self, num_classes: int = 6, dropout: float = 0.2):
        super().__init__()
        self.focus = Focus(in_channels=3, out_channels=24, kernel_size=1)

        stages = []
        in_channels = 24
        for out_channels, num_blocks, stride, reduction in self.STAGE_CONFIG:
            blocks = []
            for block_idx in range(num_blocks):
                block_stride = stride if block_idx == 0 else 1
                blocks.append(
                    SandglassBlock(
                        in_channels,
                        out_channels,
                        stride=block_stride,
                        reduction=reduction,
                    )
                )
                in_channels = out_channels
            blocks.append(SimAM())
            stages.append(nn.Sequential(*blocks))
        self.stages = nn.Sequential(*stages)

        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels, 512, kernel_size=1, bias=False),
            nn.BatchNorm2d(512),
            nn.SiLU(inplace=True),
        )
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Dropout(p=dropout),
            nn.Linear(512, num_classes),
        )
        self._initialize_weights()

    def _initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d):
                nn.init.kaiming_normal_(
                    module.weight,
                    mode="fan_out",
                    nonlinearity="relu",
                )
            elif isinstance(module, nn.BatchNorm2d):
                nn.init.ones_(module.weight)
                nn.init.zeros_(module.bias)
            elif isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, 0, 0.01)
                nn.init.zeros_(module.bias)

    def forward(self, x):
        x = self.focus(x)
        x = self.stages(x)
        x = self.conv5(x)
        return self.classifier(x)


def create_focus_rcnet(num_classes: int = 6) -> FocusRCNet:
    return FocusRCNet(num_classes=num_classes)


def make_transforms():
    """Create the exact augmentation pipeline used by Notebook 2."""
    imagenet_mean = [0.485, 0.456, 0.406]
    imagenet_std = [0.229, 0.224, 0.225]
    train_transform = A.Compose(
        [
            A.Resize(cfg.IMG_SIZE, cfg.IMG_SIZE),
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            A.RandomBrightnessContrast(p=0.5),
            A.CoarseDropout(
                num_holes_range=(1, 1),
                hole_height_range=(
                    int(cfg.IMG_SIZE * 0.05),
                    int(cfg.IMG_SIZE * 0.2),
                ),
                hole_width_range=(
                    int(cfg.IMG_SIZE * 0.05),
                    int(cfg.IMG_SIZE * 0.2),
                ),
                fill=0,
                p=0.5,
            ),
            A.Normalize(mean=imagenet_mean, std=imagenet_std),
            ToTensorV2(),
        ]
    )
    val_transform = A.Compose(
        [
            A.Resize(cfg.IMG_SIZE, cfg.IMG_SIZE),
            A.Normalize(mean=imagenet_mean, std=imagenet_std),
            ToTensorV2(),
        ]
    )
    return train_transform, val_transform


def load_or_create_split(full_dataset):
    """
    Reuse Notebook 1 indices when available.

    The fallback reproduces Notebook 1's stratified split for cases where the
    teacher checkpoint is not attached as a Kaggle input.
    """
    checkpoint_path = Path(cfg.TEACHER_CHECKPOINT_PATH)
    if checkpoint_path.is_file():
        teacher_checkpoint = torch.load(checkpoint_path, map_location="cpu")
        train_indices = teacher_checkpoint["train_indices"]
        val_indices = teacher_checkpoint["val_indices"]
        print(f"Split source: teacher checkpoint ({checkpoint_path})")
        print(
            "Teacher checkpoint best validation accuracy: "
            f"{teacher_checkpoint['best_val_acc']:.4f}"
        )
        del teacher_checkpoint
    else:
        targets = [sample[1] for sample in full_dataset.samples]
        indices = list(range(len(full_dataset)))
        train_indices, val_indices = train_test_split(
            indices,
            test_size=cfg.VAL_SPLIT,
            random_state=cfg.SEED,
            stratify=targets,
        )
        print("Split source: regenerated stratified 70/30 split with seed 42")
        print(f"Teacher checkpoint not found at: {checkpoint_path}")

    all_indices = list(train_indices) + list(val_indices)
    assert len(all_indices) == len(full_dataset)
    assert not set(train_indices).intersection(val_indices)
    assert max(all_indices) < len(full_dataset)
    return train_indices, val_indices


def prepare_data():
    train_transform, val_transform = make_transforms()
    full_dataset = datasets.ImageFolder(root=cfg.DATASET_PATH, transform=None)
    assert full_dataset.classes == cfg.CLASS_NAMES, (
        f"Expected classes {cfg.CLASS_NAMES}, found {full_dataset.classes}"
    )
    train_indices, val_indices = load_or_create_split(full_dataset)

    train_subset = Subset(full_dataset, train_indices)
    val_subset = Subset(full_dataset, val_indices)
    train_dataset = AlbumentationsDataset(train_subset, transform=train_transform)
    val_dataset = AlbumentationsDataset(val_subset, transform=val_transform)

    def worker_init_fn(worker_id):
        np.random.seed(cfg.SEED + worker_id)
        random.seed(cfg.SEED + worker_id)

    train_loader = DataLoader(
        train_dataset,
        batch_size=cfg.BATCH_SIZE,
        shuffle=True,
        num_workers=2,
        pin_memory=True,
        worker_init_fn=worker_init_fn,
        drop_last=False,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=cfg.BATCH_SIZE,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    targets = [sample[1] for sample in full_dataset.samples]
    train_dist = Counter(targets[index] for index in train_indices)
    val_dist = Counter(targets[index] for index in val_indices)

    print(f"Dataset path: {cfg.DATASET_PATH}")
    print(f"Total images: {len(full_dataset)}")
    print(f"Train images: {len(train_indices)}")
    print(f"Validation images: {len(val_indices)}")
    print(f"Train batches: {len(train_loader)}")
    print(f"Validation batches: {len(val_loader)}")
    print("\nClass distribution:")
    print(f"{'Class':<15} {'Train':>8} {'Val':>8} {'Total':>8}")
    print("-" * 42)
    for class_idx, class_name in enumerate(full_dataset.classes):
        train_count = train_dist[class_idx]
        val_count = val_dist[class_idx]
        print(
            f"{class_name:<15} {train_count:>8} "
            f"{val_count:>8} {train_count + val_count:>8}"
        )
    print("-" * 42)
    return train_loader, val_loader, train_indices, val_indices


def verify_architecture():
    model = create_focus_rcnet(cfg.NUM_CLASSES)
    total_params = sum(parameter.numel() for parameter in model.parameters())
    sample = torch.randn(1, 3, cfg.IMG_SIZE, cfg.IMG_SIZE)
    output = model(sample)
    assert total_params == 520_630, f"Unexpected parameter count: {total_params}"
    assert output.shape == (1, cfg.NUM_CLASSES), f"Unexpected shape: {output.shape}"
    print(f"Focus-RCNet parameters: {total_params:,}")
    print(f"Input shape: {list(sample.shape)}")
    print(f"Output shape: {list(output.shape)}")


def train_one_epoch(model, loader, criterion, optimizer, scaler, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in loader:
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)
        optimizer.zero_grad()
        with autocast(enabled=cfg.USE_AMP):
            outputs = model(images)
            loss = criterion(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * images.size(0)
        predictions = outputs.max(1).indices
        total += labels.size(0)
        correct += predictions.eq(labels).sum().item()
    return running_loss / total, correct / total


@torch.no_grad()
def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in loader:
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)
        with autocast(enabled=cfg.USE_AMP):
            outputs = model(images)
            loss = criterion(outputs, labels)
        running_loss += loss.item() * images.size(0)
        predictions = outputs.max(1).indices
        total += labels.size(0)
        correct += predictions.eq(labels).sum().item()
    return running_loss / total, correct / total


def run_experiment(model, train_loader, val_loader, device):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        model.parameters(),
        lr=cfg.LR,
        momentum=cfg.MOMENTUM,
        weight_decay=cfg.WEIGHT_DECAY,
    )
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.T_MAX)
    scaler = GradScaler(enabled=cfg.USE_AMP)
    history = {
        "epoch": [],
        "train_loss": [],
        "train_acc": [],
        "val_loss": [],
        "val_acc": [],
        "lr": [],
        "epoch_time": [],
    }
    best_val_acc = 0.0
    best_epoch = 0
    best_model_state = None
    total_start = time.time()

    for epoch in range(1, cfg.EPOCHS + 1):
        epoch_start = time.time()
        current_lr = optimizer.param_groups[0]["lr"]
        train_loss, train_acc = train_one_epoch(
            model,
            train_loader,
            criterion,
            optimizer,
            scaler,
            device,
        )
        val_loss, val_acc = validate(model, val_loader, criterion, device)
        scheduler.step()
        epoch_time = time.time() - epoch_start

        history["epoch"].append(epoch)
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["lr"].append(current_lr)
        history["epoch_time"].append(epoch_time)

        is_best = val_acc > best_val_acc
        if is_best:
            best_val_acc = val_acc
            best_epoch = epoch
            best_model_state = copy.deepcopy(model.state_dict())

        best_marker = " BEST" if is_best else ""
        print(
            f"Epoch [{epoch:3d}/{cfg.EPOCHS}] "
            f"| Train Loss: {train_loss:.4f} "
            f"| Train Acc: {train_acc:.4f} "
            f"| Val Loss: {val_loss:.4f} "
            f"| Val Acc: {val_acc:.4f} "
            f"| LR: {current_lr:.6f} "
            f"| Time: {epoch_time:.1f}s{best_marker}",
            flush=True,
        )

    total_time = time.time() - total_start
    return history, best_val_acc, best_epoch, best_model_state, total_time


def save_history(history, output_dir: Path):
    path = output_dir / cfg.HISTORY_FILENAME
    with path.open("w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(
            [
                "epoch",
                "train_loss",
                "train_acc",
                "val_loss",
                "val_acc",
                "lr",
                "epoch_time",
            ]
        )
        for index in range(len(history["epoch"])):
            writer.writerow(
                [
                    history["epoch"][index],
                    f"{history['train_loss'][index]:.6f}",
                    f"{history['train_acc'][index]:.6f}",
                    f"{history['val_loss'][index]:.6f}",
                    f"{history['val_acc'][index]:.6f}",
                    f"{history['lr'][index]:.8f}",
                    f"{history['epoch_time'][index]:.2f}",
                ]
            )
    return path


def save_checkpoint(
    model_state,
    history,
    best_epoch,
    best_val_acc,
    train_indices,
    val_indices,
    output_dir: Path,
):
    path = output_dir / cfg.CHECKPOINT_FILENAME
    checkpoint = {
        "model_state_dict": model_state,
        "experiment_id": cfg.EXPERIMENT_ID,
        "experiment_name": cfg.EXPERIMENT_NAME,
        "model_name": "Focus-RCNet",
        "num_classes": cfg.NUM_CLASSES,
        "class_names": cfg.CLASS_NAMES,
        "best_epoch": best_epoch,
        "best_val_acc": best_val_acc,
        "history": history,
        "config": {
            "img_size": cfg.IMG_SIZE,
            "epochs": cfg.EPOCHS,
            "batch_size": cfg.BATCH_SIZE,
            "lr": cfg.LR,
            "momentum": cfg.MOMENTUM,
            "weight_decay": cfg.WEIGHT_DECAY,
            "optimizer": cfg.OPTIMIZER,
            "scheduler": cfg.SCHEDULER,
            "t_max": cfg.T_MAX,
            "seed": cfg.SEED,
            "train_split": cfg.TRAIN_SPLIT,
            "val_split": cfg.VAL_SPLIT,
            "use_amp": cfg.USE_AMP,
            "training_mode": "cross_entropy_only",
            "knowledge_distillation": False,
        },
        "dataset_name": cfg.DATASET_NAME,
        "train_size": len(train_indices),
        "val_size": len(val_indices),
        "train_indices": train_indices,
        "val_indices": val_indices,
    }
    torch.save(checkpoint, path)
    return path


def save_summary(best_val_acc, best_epoch, total_time, output_dir: Path):
    path = output_dir / cfg.SUMMARY_FILENAME
    with path.open("w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["metric", "value"])
        writer.writerow(["experiment", cfg.EXPERIMENT_NAME])
        writer.writerow(["best_val_accuracy", f"{best_val_acc:.6f}"])
        writer.writerow(["best_val_accuracy_percent", f"{best_val_acc * 100:.2f}"])
        writer.writerow(["best_epoch", best_epoch])
        writer.writerow(["total_time_minutes", f"{total_time / 60:.2f}"])
        writer.writerow(["epochs", cfg.EPOCHS])
        writer.writerow(["batch_size", cfg.BATCH_SIZE])
        writer.writerow(["original_local_baseline_accuracy", cfg.ORIGINAL_LOCAL_BASELINE_ACC])
        writer.writerow(["paper_focus_rcnet_accuracy", cfg.PAPER_FOCUS_RCNET_ACC])
        writer.writerow(
            [
                "delta_vs_original_local_baseline_pp",
                f"{(best_val_acc - cfg.ORIGINAL_LOCAL_BASELINE_ACC) * 100:+.2f}",
            ]
        )
        writer.writerow(
            [
                "delta_vs_paper_focus_rcnet_pp",
                f"{(best_val_acc - cfg.PAPER_FOCUS_RCNET_ACC) * 100:+.2f}",
            ]
        )
    return path


def save_curves(history, output_dir: Path):
    path = output_dir / cfg.CURVES_FILENAME
    figure, axes = plt.subplots(1, 2, figsize=(13, 5))
    axes[0].plot(history["epoch"], history["train_loss"], label="Train loss")
    axes[0].plot(history["epoch"], history["val_loss"], label="Validation loss")
    axes[0].set_title("Focus-RCNet Baseline CE Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()

    axes[1].plot(history["epoch"], history["train_acc"], label="Train accuracy")
    axes[1].plot(history["epoch"], history["val_acc"], label="Validation accuracy")
    axes[1].axhline(
        cfg.ORIGINAL_LOCAL_BASELINE_ACC,
        color="tab:orange",
        linestyle="--",
        label="Original local baseline (85.24%)",
    )
    axes[1].axhline(
        cfg.PAPER_FOCUS_RCNET_ACC,
        color="tab:red",
        linestyle="--",
        label="Paper Focus-RCNet (90.00%)",
    )
    axes[1].set_title("Focus-RCNet Baseline CE Accuracy")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].grid(True, alpha=0.3)
    axes[1].legend()
    figure.tight_layout()
    figure.savefig(path, dpi=150, bbox_inches="tight")
    plt.close(figure)
    return path


def print_configuration(device):
    print("=" * 76)
    print(cfg.EXPERIMENT_NAME)
    print("=" * 76)
    print(f"Device       : {device}")
    if device.type == "cuda":
        print(f"GPU          : {torch.cuda.get_device_name(0)}")
    print(f"Dataset      : {cfg.DATASET_NAME}")
    print(f"Image size   : {cfg.IMG_SIZE}x{cfg.IMG_SIZE}")
    print(f"Epochs       : {cfg.EPOCHS}")
    print(f"Batch size   : {cfg.BATCH_SIZE}")
    print(f"Optimizer    : {cfg.OPTIMIZER}")
    print(f"Learning rate: {cfg.LR}")
    print(f"Momentum     : {cfg.MOMENTUM}")
    print(f"Weight decay : {cfg.WEIGHT_DECAY}")
    print(f"Scheduler    : {cfg.SCHEDULER} (T_max={cfg.T_MAX})")
    print(f"Loss         : CrossEntropyLoss")
    print(f"KD           : disabled")
    print(f"AMP          : {cfg.USE_AMP}")
    print(f"Seed         : {cfg.SEED}")
    print("=" * 76)


def main():
    output_dir = Path(cfg.OUTPUT_DIR)
    output_dir.mkdir(parents=True, exist_ok=True)

    seed_everything(cfg.SEED)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print_configuration(device)

    train_loader, val_loader, train_indices, val_indices = prepare_data()
    verify_architecture()

    # Reset before model initialization to preserve Notebook 2 reproducibility.
    seed_everything(cfg.SEED)
    model = create_focus_rcnet(cfg.NUM_CLASSES).to(device)
    print("\nStarting baseline CE training...", flush=True)
    history, best_val_acc, best_epoch, best_model_state, total_time = run_experiment(
        model,
        train_loader,
        val_loader,
        device,
    )

    checkpoint_path = save_checkpoint(
        best_model_state,
        history,
        best_epoch,
        best_val_acc,
        train_indices,
        val_indices,
        output_dir,
    )
    history_path = save_history(history, output_dir)
    summary_path = save_summary(best_val_acc, best_epoch, total_time, output_dir)
    curves_path = save_curves(history, output_dir)

    print("\n" + "=" * 76)
    print("Experiment complete")
    print("=" * 76)
    print(f"Best validation accuracy : {best_val_acc:.4f} ({best_val_acc * 100:.2f}%)")
    print(f"Best epoch               : {best_epoch}")
    print(f"Total time               : {total_time / 60:.1f} minutes")
    print(
        "Delta vs local 100e-bs8  : "
        f"{(best_val_acc - cfg.ORIGINAL_LOCAL_BASELINE_ACC) * 100:+.2f} pp"
    )
    print(
        "Delta vs paper baseline  : "
        f"{(best_val_acc - cfg.PAPER_FOCUS_RCNET_ACC) * 100:+.2f} pp"
    )
    print(f"Checkpoint               : {checkpoint_path}")
    print(f"History CSV              : {history_path}")
    print(f"Summary CSV              : {summary_path}")
    print(f"Training curves          : {curves_path}")
    print("=" * 76)


if __name__ == "__main__":
    main()
# Out:
# ============================================================================
# Focus-RCNet Baseline CE - 200 Epochs, Batch Size 16
# ============================================================================
# Device       : cuda
# GPU          : Tesla T4
# Dataset      : TrashNet
# Image size   : 380x380
# Epochs       : 200
# Batch size   : 16
# Optimizer    : SGD
# Learning rate: 0.05
# Momentum     : 0.9
# Weight decay : 0.0001
# Scheduler    : CosineAnnealingLR (T_max=200)
# Loss         : CrossEntropyLoss
# KD           : disabled
# AMP          : True
# Seed         : 42
# ============================================================================
# Split source: regenerated stratified 70/30 split with seed 42
# Teacher checkpoint not found at: /kaggle/input/notebooks/hamzapratama/notebook1-teacher-training/efficientnet_b4_teacher_best.pth
# Dataset path: /kaggle/input/datasets/feyzazkefe/trashnet/dataset-resized
# Total images: 2527
# Train images: 1768
# Validation images: 759
# Train batches: 111
# Validation batches: 48
#
# Class distribution:
# Class              Train      Val    Total
# ------------------------------------------
# cardboard            282      121      403
# glass                350      151      501
# metal                287      123      410
# paper                416      178      594
# plastic              337      145      482
# trash                 96       41      137
# ------------------------------------------
# Focus-RCNet parameters: 520,630
# Input shape: [1, 3, 380, 380]
# Output shape: [1, 6]
#
# Starting baseline CE training...
# /tmp/ipykernel_23/2810987272.py:493: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=cfg.USE_AMP)
# /tmp/ipykernel_23/2810987272.py:451: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=cfg.USE_AMP):
# /tmp/ipykernel_23/2810987272.py:474: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=cfg.USE_AMP):
# Epoch [  1/200] | Train Loss: 1.6928 | Train Acc: 0.3258 | Val Loss: 9.0186 | Val Acc: 0.1765 | LR: 0.050000 | Time: 32.0s BEST
# Epoch [  2/200] | Train Loss: 1.5286 | Train Acc: 0.4152 | Val Loss: 1.5381 | Val Acc: 0.4124 | LR: 0.049997 | Time: 11.5s BEST
# Epoch [  3/200] | Train Loss: 1.4173 | Train Acc: 0.4440 | Val Loss: 1.4468 | Val Acc: 0.5310 | LR: 0.049988 | Time: 11.3s BEST
# Epoch [  4/200] | Train Loss: 1.3773 | Train Acc: 0.4604 | Val Loss: 1.3366 | Val Acc: 0.5007 | LR: 0.049972 | Time: 11.4s
# Epoch [  5/200] | Train Loss: 1.3157 | Train Acc: 0.4972 | Val Loss: 1.3668 | Val Acc: 0.4177 | LR: 0.049951 | Time: 11.6s
# Epoch [  6/200] | Train Loss: 1.2728 | Train Acc: 0.5079 | Val Loss: 1.1445 | Val Acc: 0.5639 | LR: 0.049923 | Time: 11.5s BEST
# Epoch [  7/200] | Train Loss: 1.2125 | Train Acc: 0.5187 | Val Loss: 1.2652 | Val Acc: 0.5310 | LR: 0.049889 | Time: 11.3s
# Epoch [  8/200] | Train Loss: 1.1947 | Train Acc: 0.5469 | Val Loss: 1.0998 | Val Acc: 0.5586 | LR: 0.049849 | Time: 11.4s
# Epoch [  9/200] | Train Loss: 1.1179 | Train Acc: 0.5673 | Val Loss: 0.9936 | Val Acc: 0.6364 | LR: 0.049803 | Time: 11.4s BEST
# Epoch [ 10/200] | Train Loss: 1.1147 | Train Acc: 0.5752 | Val Loss: 1.0349 | Val Acc: 0.6074 | LR: 0.049751 | Time: 11.5s
# Epoch [ 11/200] | Train Loss: 1.0354 | Train Acc: 0.6046 | Val Loss: 1.0296 | Val Acc: 0.6192 | LR: 0.049692 | Time: 11.6s
# Epoch [ 12/200] | Train Loss: 1.0176 | Train Acc: 0.6097 | Val Loss: 0.9450 | Val Acc: 0.6337 | LR: 0.049628 | Time: 11.5s
# Epoch [ 13/200] | Train Loss: 0.9691 | Train Acc: 0.6278 | Val Loss: 0.9154 | Val Acc: 0.6311 | LR: 0.049557 | Time: 11.7s
# Epoch [ 14/200] | Train Loss: 0.9572 | Train Acc: 0.6391 | Val Loss: 0.9689 | Val Acc: 0.6364 | LR: 0.049481 | Time: 11.7s
# Epoch [ 15/200] | Train Loss: 0.9614 | Train Acc: 0.6380 | Val Loss: 1.2450 | Val Acc: 0.5402 | LR: 0.049398 | Time: 11.7s
# Epoch [ 16/200] | Train Loss: 0.8932 | Train Acc: 0.6697 | Val Loss: 0.9798 | Val Acc: 0.6561 | LR: 0.049309 | Time: 11.8s BEST
# Epoch [ 17/200] | Train Loss: 0.8709 | Train Acc: 0.6623 | Val Loss: 0.9899 | Val Acc: 0.6166 | LR: 0.049215 | Time: 11.7s
# Epoch [ 18/200] | Train Loss: 0.8458 | Train Acc: 0.6776 | Val Loss: 0.8644 | Val Acc: 0.6667 | LR: 0.049114 | Time: 11.5s BEST
# Epoch [ 19/200] | Train Loss: 0.8351 | Train Acc: 0.6912 | Val Loss: 0.7817 | Val Acc: 0.7101 | LR: 0.049007 | Time: 11.6s BEST
# Epoch [ 20/200] | Train Loss: 0.8015 | Train Acc: 0.7132 | Val Loss: 0.7756 | Val Acc: 0.7181 | LR: 0.048895 | Time: 11.5s BEST
# Epoch [ 21/200] | Train Loss: 0.7446 | Train Acc: 0.7274 | Val Loss: 0.9317 | Val Acc: 0.6864 | LR: 0.048776 | Time: 11.6s
# Epoch [ 22/200] | Train Loss: 0.7449 | Train Acc: 0.7245 | Val Loss: 1.0888 | Val Acc: 0.6166 | LR: 0.048652 | Time: 11.7s
# Epoch [ 23/200] | Train Loss: 0.6969 | Train Acc: 0.7438 | Val Loss: 0.9288 | Val Acc: 0.6930 | LR: 0.048522 | Time: 11.6s
# Epoch [ 24/200] | Train Loss: 0.7118 | Train Acc: 0.7443 | Val Loss: 0.8944 | Val Acc: 0.6943 | LR: 0.048386 | Time: 11.8s
# Epoch [ 25/200] | Train Loss: 0.6865 | Train Acc: 0.7506 | Val Loss: 0.8473 | Val Acc: 0.7062 | LR: 0.048244 | Time: 11.6s
# Epoch [ 26/200] | Train Loss: 0.6933 | Train Acc: 0.7460 | Val Loss: 0.7595 | Val Acc: 0.7299 | LR: 0.048097 | Time: 11.6s BEST
# Epoch [ 27/200] | Train Loss: 0.6527 | Train Acc: 0.7743 | Val Loss: 0.8565 | Val Acc: 0.7075 | LR: 0.047944 | Time: 11.7s
# Epoch [ 28/200] | Train Loss: 0.6631 | Train Acc: 0.7636 | Val Loss: 0.7139 | Val Acc: 0.7576 | LR: 0.047785 | Time: 11.6s BEST
# Epoch [ 29/200] | Train Loss: 0.5757 | Train Acc: 0.7885 | Val Loss: 0.9221 | Val Acc: 0.6851 | LR: 0.047621 | Time: 11.8s
# Epoch [ 30/200] | Train Loss: 0.6291 | Train Acc: 0.7687 | Val Loss: 0.8982 | Val Acc: 0.6891 | LR: 0.047451 | Time: 11.8s
# Epoch [ 31/200] | Train Loss: 0.6471 | Train Acc: 0.7670 | Val Loss: 0.6635 | Val Acc: 0.7760 | LR: 0.047275 | Time: 11.8s BEST
# Epoch [ 32/200] | Train Loss: 0.5583 | Train Acc: 0.7947 | Val Loss: 0.6955 | Val Acc: 0.7602 | LR: 0.047094 | Time: 11.8s
# Epoch [ 33/200] | Train Loss: 0.5629 | Train Acc: 0.7902 | Val Loss: 0.6898 | Val Acc: 0.7431 | LR: 0.046908 | Time: 11.8s
# Epoch [ 34/200] | Train Loss: 0.5234 | Train Acc: 0.8184 | Val Loss: 0.6954 | Val Acc: 0.7905 | LR: 0.046716 | Time: 11.8s BEST
# Epoch [ 35/200] | Train Loss: 0.5522 | Train Acc: 0.8032 | Val Loss: 0.6796 | Val Acc: 0.7563 | LR: 0.046519 | Time: 11.8s
# Epoch [ 36/200] | Train Loss: 0.5288 | Train Acc: 0.8162 | Val Loss: 0.7263 | Val Acc: 0.7628 | LR: 0.046316 | Time: 11.7s
# Epoch [ 37/200] | Train Loss: 0.4976 | Train Acc: 0.8241 | Val Loss: 0.8225 | Val Acc: 0.7194 | LR: 0.046108 | Time: 11.6s
# Epoch [ 38/200] | Train Loss: 0.4883 | Train Acc: 0.8156 | Val Loss: 0.6693 | Val Acc: 0.7615 | LR: 0.045895 | Time: 11.7s
# Epoch [ 39/200] | Train Loss: 0.4651 | Train Acc: 0.8343 | Val Loss: 0.6483 | Val Acc: 0.7760 | LR: 0.045677 | Time: 11.8s
# Epoch [ 40/200] | Train Loss: 0.4366 | Train Acc: 0.8462 | Val Loss: 0.8112 | Val Acc: 0.7391 | LR: 0.045454 | Time: 11.6s
# Epoch [ 41/200] | Train Loss: 0.4743 | Train Acc: 0.8269 | Val Loss: 0.6600 | Val Acc: 0.7866 | LR: 0.045225 | Time: 11.8s
# Epoch [ 42/200] | Train Loss: 0.4545 | Train Acc: 0.8286 | Val Loss: 1.0438 | Val Acc: 0.6733 | LR: 0.044992 | Time: 11.5s
# Epoch [ 43/200] | Train Loss: 0.4401 | Train Acc: 0.8416 | Val Loss: 0.8007 | Val Acc: 0.7536 | LR: 0.044754 | Time: 11.7s
# Epoch [ 44/200] | Train Loss: 0.4023 | Train Acc: 0.8507 | Val Loss: 0.9032 | Val Acc: 0.6983 | LR: 0.044511 | Time: 11.6s
# Epoch [ 45/200] | Train Loss: 0.3942 | Train Acc: 0.8609 | Val Loss: 1.2499 | Val Acc: 0.6601 | LR: 0.044263 | Time: 11.7s
# Epoch [ 46/200] | Train Loss: 0.4521 | Train Acc: 0.8456 | Val Loss: 0.7427 | Val Acc: 0.7747 | LR: 0.044010 | Time: 11.6s
# Epoch [ 47/200] | Train Loss: 0.3684 | Train Acc: 0.8733 | Val Loss: 0.7829 | Val Acc: 0.7734 | LR: 0.043753 | Time: 11.6s
# Epoch [ 48/200] | Train Loss: 0.4033 | Train Acc: 0.8705 | Val Loss: 0.7329 | Val Acc: 0.7563 | LR: 0.043491 | Time: 11.6s
# Epoch [ 49/200] | Train Loss: 0.3954 | Train Acc: 0.8529 | Val Loss: 0.7670 | Val Acc: 0.7510 | LR: 0.043224 | Time: 11.7s
# Epoch [ 50/200] | Train Loss: 0.3725 | Train Acc: 0.8563 | Val Loss: 0.6746 | Val Acc: 0.7813 | LR: 0.042953 | Time: 11.7s
# Epoch [ 51/200] | Train Loss: 0.3610 | Train Acc: 0.8631 | Val Loss: 0.7182 | Val Acc: 0.7655 | LR: 0.042678 | Time: 11.8s
# Epoch [ 52/200] | Train Loss: 0.3620 | Train Acc: 0.8705 | Val Loss: 0.6962 | Val Acc: 0.7773 | LR: 0.042398 | Time: 11.6s
# Epoch [ 53/200] | Train Loss: 0.3664 | Train Acc: 0.8705 | Val Loss: 0.6804 | Val Acc: 0.7787 | LR: 0.042114 | Time: 11.6s
# Epoch [ 54/200] | Train Loss: 0.3325 | Train Acc: 0.8801 | Val Loss: 0.7177 | Val Acc: 0.7905 | LR: 0.041825 | Time: 11.7s
# Epoch [ 55/200] | Train Loss: 0.3407 | Train Acc: 0.8824 | Val Loss: 0.7902 | Val Acc: 0.7642 | LR: 0.041533 | Time: 11.8s
# Epoch [ 56/200] | Train Loss: 0.3415 | Train Acc: 0.8857 | Val Loss: 0.6848 | Val Acc: 0.7852 | LR: 0.041236 | Time: 11.7s
# Epoch [ 57/200] | Train Loss: 0.3197 | Train Acc: 0.8908 | Val Loss: 0.7615 | Val Acc: 0.7404 | LR: 0.040936 | Time: 11.7s
# Epoch [ 58/200] | Train Loss: 0.3131 | Train Acc: 0.8908 | Val Loss: 0.6907 | Val Acc: 0.7760 | LR: 0.040631 | Time: 11.6s
# Epoch [ 59/200] | Train Loss: 0.2898 | Train Acc: 0.8982 | Val Loss: 0.7638 | Val Acc: 0.7826 | LR: 0.040323 | Time: 11.5s
# Epoch [ 60/200] | Train Loss: 0.2878 | Train Acc: 0.8971 | Val Loss: 0.8643 | Val Acc: 0.7470 | LR: 0.040011 | Time: 11.5s
# Epoch [ 61/200] | Train Loss: 0.3155 | Train Acc: 0.8920 | Val Loss: 0.6220 | Val Acc: 0.8050 | LR: 0.039695 | Time: 11.7s BEST
# Epoch [ 62/200] | Train Loss: 0.2893 | Train Acc: 0.8954 | Val Loss: 0.7394 | Val Acc: 0.7984 | LR: 0.039375 | Time: 11.7s
# Epoch [ 63/200] | Train Loss: 0.3101 | Train Acc: 0.8914 | Val Loss: 0.6600 | Val Acc: 0.7931 | LR: 0.039052 | Time: 11.6s
# Epoch [ 64/200] | Train Loss: 0.2890 | Train Acc: 0.8942 | Val Loss: 0.7489 | Val Acc: 0.7879 | LR: 0.038726 | Time: 11.6s
# Epoch [ 65/200] | Train Loss: 0.3007 | Train Acc: 0.8891 | Val Loss: 0.7208 | Val Acc: 0.8011 | LR: 0.038396 | Time: 11.7s
# Epoch [ 66/200] | Train Loss: 0.2737 | Train Acc: 0.9005 | Val Loss: 0.7182 | Val Acc: 0.7984 | LR: 0.038062 | Time: 11.7s
# Epoch [ 67/200] | Train Loss: 0.2822 | Train Acc: 0.9027 | Val Loss: 0.8456 | Val Acc: 0.7510 | LR: 0.037726 | Time: 11.7s
# Epoch [ 68/200] | Train Loss: 0.2549 | Train Acc: 0.9038 | Val Loss: 0.6856 | Val Acc: 0.8050 | LR: 0.037386 | Time: 11.7s
# Epoch [ 69/200] | Train Loss: 0.2306 | Train Acc: 0.9219 | Val Loss: 0.8713 | Val Acc: 0.7694 | LR: 0.037044 | Time: 11.7s
# Epoch [ 70/200] | Train Loss: 0.2454 | Train Acc: 0.9152 | Val Loss: 0.6911 | Val Acc: 0.8063 | LR: 0.036698 | Time: 11.7s BEST
# Epoch [ 71/200] | Train Loss: 0.2351 | Train Acc: 0.9095 | Val Loss: 0.6816 | Val Acc: 0.7971 | LR: 0.036350 | Time: 11.7s
# Epoch [ 72/200] | Train Loss: 0.2444 | Train Acc: 0.9089 | Val Loss: 0.7419 | Val Acc: 0.7800 | LR: 0.035998 | Time: 11.6s
# Epoch [ 73/200] | Train Loss: 0.2208 | Train Acc: 0.9225 | Val Loss: 0.7853 | Val Acc: 0.7852 | LR: 0.035644 | Time: 11.5s
# Epoch [ 74/200] | Train Loss: 0.1853 | Train Acc: 0.9395 | Val Loss: 0.7493 | Val Acc: 0.7826 | LR: 0.035288 | Time: 11.5s
# Epoch [ 75/200] | Train Loss: 0.2418 | Train Acc: 0.9140 | Val Loss: 0.6778 | Val Acc: 0.7958 | LR: 0.034929 | Time: 11.6s
# Epoch [ 76/200] | Train Loss: 0.2161 | Train Acc: 0.9208 | Val Loss: 0.5614 | Val Acc: 0.8366 | LR: 0.034567 | Time: 11.8s BEST
# Epoch [ 77/200] | Train Loss: 0.2194 | Train Acc: 0.9259 | Val Loss: 0.7138 | Val Acc: 0.7997 | LR: 0.034203 | Time: 11.7s
# Epoch [ 78/200] | Train Loss: 0.2071 | Train Acc: 0.9304 | Val Loss: 0.6394 | Val Acc: 0.8011 | LR: 0.033837 | Time: 11.8s
# Epoch [ 79/200] | Train Loss: 0.1704 | Train Acc: 0.9423 | Val Loss: 0.6553 | Val Acc: 0.8208 | LR: 0.033468 | Time: 11.8s
# Epoch [ 80/200] | Train Loss: 0.1891 | Train Acc: 0.9361 | Val Loss: 0.6666 | Val Acc: 0.8063 | LR: 0.033098 | Time: 11.7s
# Epoch [ 81/200] | Train Loss: 0.1977 | Train Acc: 0.9383 | Val Loss: 0.6647 | Val Acc: 0.8169 | LR: 0.032725 | Time: 11.8s
# Epoch [ 82/200] | Train Loss: 0.1765 | Train Acc: 0.9372 | Val Loss: 0.6425 | Val Acc: 0.8129 | LR: 0.032351 | Time: 11.6s
# Epoch [ 83/200] | Train Loss: 0.2034 | Train Acc: 0.9316 | Val Loss: 0.7055 | Val Acc: 0.8037 | LR: 0.031975 | Time: 11.8s
# Epoch [ 84/200] | Train Loss: 0.1811 | Train Acc: 0.9361 | Val Loss: 0.8135 | Val Acc: 0.7760 | LR: 0.031597 | Time: 11.8s
# Epoch [ 85/200] | Train Loss: 0.1820 | Train Acc: 0.9406 | Val Loss: 0.6362 | Val Acc: 0.8155 | LR: 0.031217 | Time: 11.8s
# Epoch [ 86/200] | Train Loss: 0.1384 | Train Acc: 0.9548 | Val Loss: 0.6701 | Val Acc: 0.8116 | LR: 0.030836 | Time: 11.9s
# Epoch [ 87/200] | Train Loss: 0.1421 | Train Acc: 0.9463 | Val Loss: 0.6254 | Val Acc: 0.8274 | LR: 0.030454 | Time: 11.8s
# Epoch [ 88/200] | Train Loss: 0.1458 | Train Acc: 0.9480 | Val Loss: 0.7772 | Val Acc: 0.7958 | LR: 0.030070 | Time: 11.9s
# Epoch [ 89/200] | Train Loss: 0.1692 | Train Acc: 0.9395 | Val Loss: 0.6898 | Val Acc: 0.8287 | LR: 0.029685 | Time: 11.9s
# Epoch [ 90/200] | Train Loss: 0.1804 | Train Acc: 0.9378 | Val Loss: 0.7116 | Val Acc: 0.7945 | LR: 0.029298 | Time: 11.9s
# Epoch [ 91/200] | Train Loss: 0.1529 | Train Acc: 0.9485 | Val Loss: 0.6463 | Val Acc: 0.8208 | LR: 0.028911 | Time: 11.7s
# Epoch [ 92/200] | Train Loss: 0.1543 | Train Acc: 0.9485 | Val Loss: 0.6689 | Val Acc: 0.8221 | LR: 0.028523 | Time: 11.7s
# Epoch [ 93/200] | Train Loss: 0.1103 | Train Acc: 0.9655 | Val Loss: 0.7261 | Val Acc: 0.8195 | LR: 0.028133 | Time: 11.8s
# Epoch [ 94/200] | Train Loss: 0.1452 | Train Acc: 0.9502 | Val Loss: 0.8768 | Val Acc: 0.7787 | LR: 0.027743 | Time: 11.8s
# Epoch [ 95/200] | Train Loss: 0.1457 | Train Acc: 0.9502 | Val Loss: 0.5870 | Val Acc: 0.8327 | LR: 0.027353 | Time: 11.9s
# Epoch [ 96/200] | Train Loss: 0.1051 | Train Acc: 0.9638 | Val Loss: 0.6770 | Val Acc: 0.8261 | LR: 0.026961 | Time: 11.8s
# Epoch [ 97/200] | Train Loss: 0.1255 | Train Acc: 0.9564 | Val Loss: 0.7038 | Val Acc: 0.8169 | LR: 0.026570 | Time: 12.1s
# Epoch [ 98/200] | Train Loss: 0.1198 | Train Acc: 0.9548 | Val Loss: 0.6975 | Val Acc: 0.8248 | LR: 0.026178 | Time: 11.9s
# Epoch [ 99/200] | Train Loss: 0.1277 | Train Acc: 0.9581 | Val Loss: 0.7713 | Val Acc: 0.8076 | LR: 0.025785 | Time: 11.8s
# Epoch [100/200] | Train Loss: 0.1602 | Train Acc: 0.9457 | Val Loss: 0.7270 | Val Acc: 0.8155 | LR: 0.025393 | Time: 11.8s
# Epoch [101/200] | Train Loss: 0.1201 | Train Acc: 0.9576 | Val Loss: 0.6701 | Val Acc: 0.8393 | LR: 0.025000 | Time: 11.9s BEST
# Epoch [102/200] | Train Loss: 0.0989 | Train Acc: 0.9661 | Val Loss: 0.7231 | Val Acc: 0.8393 | LR: 0.024607 | Time: 11.6s
# Epoch [103/200] | Train Loss: 0.0857 | Train Acc: 0.9700 | Val Loss: 0.7508 | Val Acc: 0.8235 | LR: 0.024215 | Time: 11.7s
# Epoch [104/200] | Train Loss: 0.0940 | Train Acc: 0.9655 | Val Loss: 0.7578 | Val Acc: 0.8129 | LR: 0.023822 | Time: 11.6s
# Epoch [105/200] | Train Loss: 0.0770 | Train Acc: 0.9729 | Val Loss: 0.6137 | Val Acc: 0.8419 | LR: 0.023430 | Time: 11.8s BEST
# Epoch [106/200] | Train Loss: 0.0967 | Train Acc: 0.9661 | Val Loss: 0.8377 | Val Acc: 0.8103 | LR: 0.023039 | Time: 11.7s
# Epoch [107/200] | Train Loss: 0.1232 | Train Acc: 0.9587 | Val Loss: 0.8025 | Val Acc: 0.8169 | LR: 0.022647 | Time: 11.5s
# Epoch [108/200] | Train Loss: 0.1202 | Train Acc: 0.9610 | Val Loss: 0.7938 | Val Acc: 0.8155 | LR: 0.022257 | Time: 11.8s
# Epoch [109/200] | Train Loss: 0.0983 | Train Acc: 0.9615 | Val Loss: 0.6592 | Val Acc: 0.8235 | LR: 0.021867 | Time: 11.9s
# Epoch [110/200] | Train Loss: 0.0875 | Train Acc: 0.9729 | Val Loss: 0.6260 | Val Acc: 0.8472 | LR: 0.021477 | Time: 11.8s BEST
# Epoch [111/200] | Train Loss: 0.0805 | Train Acc: 0.9745 | Val Loss: 0.7307 | Val Acc: 0.8274 | LR: 0.021089 | Time: 12.0s
# Epoch [112/200] | Train Loss: 0.0864 | Train Acc: 0.9695 | Val Loss: 0.7055 | Val Acc: 0.8366 | LR: 0.020702 | Time: 11.8s
# Epoch [113/200] | Train Loss: 0.0758 | Train Acc: 0.9757 | Val Loss: 0.7184 | Val Acc: 0.8274 | LR: 0.020315 | Time: 11.8s
# Epoch [114/200] | Train Loss: 0.0746 | Train Acc: 0.9785 | Val Loss: 0.7113 | Val Acc: 0.8327 | LR: 0.019930 | Time: 11.9s
# Epoch [115/200] | Train Loss: 0.0866 | Train Acc: 0.9723 | Val Loss: 0.7559 | Val Acc: 0.8221 | LR: 0.019546 | Time: 11.8s
# Epoch [116/200] | Train Loss: 0.0771 | Train Acc: 0.9745 | Val Loss: 0.6342 | Val Acc: 0.8406 | LR: 0.019164 | Time: 11.9s
# Epoch [117/200] | Train Loss: 0.0779 | Train Acc: 0.9751 | Val Loss: 0.7635 | Val Acc: 0.8037 | LR: 0.018783 | Time: 11.7s
# Epoch [118/200] | Train Loss: 0.0697 | Train Acc: 0.9757 | Val Loss: 0.6998 | Val Acc: 0.8261 | LR: 0.018403 | Time: 11.8s
# Epoch [119/200] | Train Loss: 0.0666 | Train Acc: 0.9762 | Val Loss: 0.6469 | Val Acc: 0.8498 | LR: 0.018025 | Time: 11.9s BEST
# Epoch [120/200] | Train Loss: 0.0487 | Train Acc: 0.9847 | Val Loss: 0.6841 | Val Acc: 0.8379 | LR: 0.017649 | Time: 11.8s
# Epoch [121/200] | Train Loss: 0.0662 | Train Acc: 0.9808 | Val Loss: 0.7200 | Val Acc: 0.8248 | LR: 0.017275 | Time: 11.8s
# Epoch [122/200] | Train Loss: 0.0808 | Train Acc: 0.9762 | Val Loss: 0.7551 | Val Acc: 0.8208 | LR: 0.016902 | Time: 11.7s
# Epoch [123/200] | Train Loss: 0.0611 | Train Acc: 0.9808 | Val Loss: 0.7559 | Val Acc: 0.8235 | LR: 0.016532 | Time: 11.9s
# Epoch [124/200] | Train Loss: 0.0536 | Train Acc: 0.9825 | Val Loss: 0.7063 | Val Acc: 0.8327 | LR: 0.016163 | Time: 11.8s
# Epoch [125/200] | Train Loss: 0.0373 | Train Acc: 0.9887 | Val Loss: 0.6598 | Val Acc: 0.8419 | LR: 0.015797 | Time: 11.7s
# Epoch [126/200] | Train Loss: 0.0462 | Train Acc: 0.9876 | Val Loss: 0.7009 | Val Acc: 0.8393 | LR: 0.015433 | Time: 11.7s
# Epoch [127/200] | Train Loss: 0.0377 | Train Acc: 0.9870 | Val Loss: 0.6974 | Val Acc: 0.8366 | LR: 0.015071 | Time: 11.7s
# Epoch [128/200] | Train Loss: 0.0475 | Train Acc: 0.9853 | Val Loss: 0.6269 | Val Acc: 0.8551 | LR: 0.014712 | Time: 11.7s BEST
# Epoch [129/200] | Train Loss: 0.0354 | Train Acc: 0.9876 | Val Loss: 0.6816 | Val Acc: 0.8472 | LR: 0.014356 | Time: 11.9s
# Epoch [130/200] | Train Loss: 0.0491 | Train Acc: 0.9853 | Val Loss: 0.6813 | Val Acc: 0.8445 | LR: 0.014002 | Time: 11.8s
# Epoch [131/200] | Train Loss: 0.0503 | Train Acc: 0.9859 | Val Loss: 0.6341 | Val Acc: 0.8485 | LR: 0.013650 | Time: 11.7s
# Epoch [132/200] | Train Loss: 0.0339 | Train Acc: 0.9898 | Val Loss: 0.6507 | Val Acc: 0.8393 | LR: 0.013302 | Time: 11.7s
# Epoch [133/200] | Train Loss: 0.0368 | Train Acc: 0.9915 | Val Loss: 0.6651 | Val Acc: 0.8511 | LR: 0.012956 | Time: 11.6s
# Epoch [134/200] | Train Loss: 0.0348 | Train Acc: 0.9893 | Val Loss: 0.6268 | Val Acc: 0.8498 | LR: 0.012614 | Time: 11.8s
# Epoch [135/200] | Train Loss: 0.0303 | Train Acc: 0.9910 | Val Loss: 0.6444 | Val Acc: 0.8366 | LR: 0.012274 | Time: 11.8s
# Epoch [136/200] | Train Loss: 0.0481 | Train Acc: 0.9847 | Val Loss: 0.6235 | Val Acc: 0.8458 | LR: 0.011938 | Time: 11.8s
# Epoch [137/200] | Train Loss: 0.0331 | Train Acc: 0.9915 | Val Loss: 0.6789 | Val Acc: 0.8419 | LR: 0.011604 | Time: 11.9s
# Epoch [138/200] | Train Loss: 0.0326 | Train Acc: 0.9859 | Val Loss: 0.6588 | Val Acc: 0.8366 | LR: 0.011274 | Time: 11.7s
# Epoch [139/200] | Train Loss: 0.0297 | Train Acc: 0.9932 | Val Loss: 0.7139 | Val Acc: 0.8379 | LR: 0.010948 | Time: 11.8s
# Epoch [140/200] | Train Loss: 0.0323 | Train Acc: 0.9932 | Val Loss: 0.6892 | Val Acc: 0.8485 | LR: 0.010625 | Time: 11.9s
# Epoch [141/200] | Train Loss: 0.0341 | Train Acc: 0.9870 | Val Loss: 0.6626 | Val Acc: 0.8393 | LR: 0.010305 | Time: 11.8s
# Epoch [142/200] | Train Loss: 0.0449 | Train Acc: 0.9859 | Val Loss: 0.6542 | Val Acc: 0.8327 | LR: 0.009989 | Time: 11.7s
# Epoch [143/200] | Train Loss: 0.0297 | Train Acc: 0.9915 | Val Loss: 0.6481 | Val Acc: 0.8498 | LR: 0.009677 | Time: 11.8s
# Epoch [144/200] | Train Loss: 0.0354 | Train Acc: 0.9904 | Val Loss: 0.6528 | Val Acc: 0.8498 | LR: 0.009369 | Time: 12.1s
# Epoch [145/200] | Train Loss: 0.0196 | Train Acc: 0.9949 | Val Loss: 0.6666 | Val Acc: 0.8485 | LR: 0.009064 | Time: 11.8s
# Epoch [146/200] | Train Loss: 0.0222 | Train Acc: 0.9915 | Val Loss: 0.6349 | Val Acc: 0.8564 | LR: 0.008764 | Time: 11.8s BEST
# Epoch [147/200] | Train Loss: 0.0211 | Train Acc: 0.9949 | Val Loss: 0.6771 | Val Acc: 0.8379 | LR: 0.008467 | Time: 11.8s
# Epoch [148/200] | Train Loss: 0.0218 | Train Acc: 0.9915 | Val Loss: 0.6478 | Val Acc: 0.8445 | LR: 0.008175 | Time: 11.5s
# Epoch [149/200] | Train Loss: 0.0215 | Train Acc: 0.9921 | Val Loss: 0.6686 | Val Acc: 0.8419 | LR: 0.007886 | Time: 11.6s
# Epoch [150/200] | Train Loss: 0.0264 | Train Acc: 0.9921 | Val Loss: 0.6307 | Val Acc: 0.8432 | LR: 0.007602 | Time: 12.0s
# Epoch [151/200] | Train Loss: 0.0197 | Train Acc: 0.9955 | Val Loss: 0.6268 | Val Acc: 0.8511 | LR: 0.007322 | Time: 11.7s
# Epoch [152/200] | Train Loss: 0.0262 | Train Acc: 0.9932 | Val Loss: 0.6595 | Val Acc: 0.8577 | LR: 0.007047 | Time: 11.7s BEST
# Epoch [153/200] | Train Loss: 0.0267 | Train Acc: 0.9910 | Val Loss: 0.6437 | Val Acc: 0.8511 | LR: 0.006776 | Time: 11.9s
# Epoch [154/200] | Train Loss: 0.0194 | Train Acc: 0.9949 | Val Loss: 0.6092 | Val Acc: 0.8564 | LR: 0.006509 | Time: 11.8s
# Epoch [155/200] | Train Loss: 0.0176 | Train Acc: 0.9960 | Val Loss: 0.6297 | Val Acc: 0.8564 | LR: 0.006247 | Time: 11.7s
# Epoch [156/200] | Train Loss: 0.0207 | Train Acc: 0.9943 | Val Loss: 0.6293 | Val Acc: 0.8564 | LR: 0.005990 | Time: 11.8s
# Epoch [157/200] | Train Loss: 0.0241 | Train Acc: 0.9926 | Val Loss: 0.6851 | Val Acc: 0.8458 | LR: 0.005737 | Time: 11.6s
# Epoch [158/200] | Train Loss: 0.0256 | Train Acc: 0.9932 | Val Loss: 0.6795 | Val Acc: 0.8432 | LR: 0.005489 | Time: 11.7s
# Epoch [159/200] | Train Loss: 0.0238 | Train Acc: 0.9932 | Val Loss: 0.6405 | Val Acc: 0.8445 | LR: 0.005246 | Time: 11.8s
# Epoch [160/200] | Train Loss: 0.0223 | Train Acc: 0.9938 | Val Loss: 0.6499 | Val Acc: 0.8511 | LR: 0.005008 | Time: 11.7s
# Epoch [161/200] | Train Loss: 0.0202 | Train Acc: 0.9921 | Val Loss: 0.6593 | Val Acc: 0.8458 | LR: 0.004775 | Time: 11.8s
# Epoch [162/200] | Train Loss: 0.0172 | Train Acc: 0.9955 | Val Loss: 0.6398 | Val Acc: 0.8577 | LR: 0.004546 | Time: 11.8s
# Epoch [163/200] | Train Loss: 0.0198 | Train Acc: 0.9943 | Val Loss: 0.6546 | Val Acc: 0.8538 | LR: 0.004323 | Time: 11.6s
# Epoch [164/200] | Train Loss: 0.0240 | Train Acc: 0.9926 | Val Loss: 0.6871 | Val Acc: 0.8538 | LR: 0.004105 | Time: 11.6s
# Epoch [165/200] | Train Loss: 0.0183 | Train Acc: 0.9932 | Val Loss: 0.6658 | Val Acc: 0.8524 | LR: 0.003892 | Time: 11.8s
# Epoch [166/200] | Train Loss: 0.0124 | Train Acc: 0.9983 | Val Loss: 0.6572 | Val Acc: 0.8551 | LR: 0.003684 | Time: 11.6s
# Epoch [167/200] | Train Loss: 0.0196 | Train Acc: 0.9932 | Val Loss: 0.6471 | Val Acc: 0.8485 | LR: 0.003481 | Time: 11.8s
# Epoch [168/200] | Train Loss: 0.0211 | Train Acc: 0.9932 | Val Loss: 0.6598 | Val Acc: 0.8445 | LR: 0.003284 | Time: 11.7s
# Epoch [169/200] | Train Loss: 0.0132 | Train Acc: 0.9960 | Val Loss: 0.6523 | Val Acc: 0.8511 | LR: 0.003092 | Time: 11.6s
# Epoch [170/200] | Train Loss: 0.0124 | Train Acc: 0.9983 | Val Loss: 0.6539 | Val Acc: 0.8538 | LR: 0.002906 | Time: 11.9s
# Epoch [171/200] | Train Loss: 0.0177 | Train Acc: 0.9955 | Val Loss: 0.6680 | Val Acc: 0.8498 | LR: 0.002725 | Time: 11.8s
# Epoch [172/200] | Train Loss: 0.0184 | Train Acc: 0.9955 | Val Loss: 0.6453 | Val Acc: 0.8538 | LR: 0.002549 | Time: 11.7s
# Epoch [173/200] | Train Loss: 0.0146 | Train Acc: 0.9966 | Val Loss: 0.6676 | Val Acc: 0.8498 | LR: 0.002379 | Time: 11.8s
# Epoch [174/200] | Train Loss: 0.0152 | Train Acc: 0.9949 | Val Loss: 0.6558 | Val Acc: 0.8538 | LR: 0.002215 | Time: 11.8s
# Epoch [175/200] | Train Loss: 0.0187 | Train Acc: 0.9938 | Val Loss: 0.6593 | Val Acc: 0.8630 | LR: 0.002056 | Time: 11.6s BEST
# Epoch [176/200] | Train Loss: 0.0147 | Train Acc: 0.9960 | Val Loss: 0.6722 | Val Acc: 0.8538 | LR: 0.001903 | Time: 11.8s
# Epoch [177/200] | Train Loss: 0.0158 | Train Acc: 0.9960 | Val Loss: 0.6699 | Val Acc: 0.8538 | LR: 0.001756 | Time: 11.6s
# Epoch [178/200] | Train Loss: 0.0167 | Train Acc: 0.9949 | Val Loss: 0.6720 | Val Acc: 0.8498 | LR: 0.001614 | Time: 11.6s
# Epoch [179/200] | Train Loss: 0.0126 | Train Acc: 0.9972 | Val Loss: 0.6686 | Val Acc: 0.8472 | LR: 0.001478 | Time: 11.6s
# Epoch [180/200] | Train Loss: 0.0165 | Train Acc: 0.9966 | Val Loss: 0.6866 | Val Acc: 0.8445 | LR: 0.001348 | Time: 11.9s
# Epoch [181/200] | Train Loss: 0.0084 | Train Acc: 0.9989 | Val Loss: 0.6807 | Val Acc: 0.8511 | LR: 0.001224 | Time: 11.9s
# Epoch [182/200] | Train Loss: 0.0169 | Train Acc: 0.9960 | Val Loss: 0.6710 | Val Acc: 0.8472 | LR: 0.001105 | Time: 11.6s
# Epoch [183/200] | Train Loss: 0.0145 | Train Acc: 0.9972 | Val Loss: 0.6690 | Val Acc: 0.8472 | LR: 0.000993 | Time: 11.7s
# Epoch [184/200] | Train Loss: 0.0115 | Train Acc: 0.9960 | Val Loss: 0.6463 | Val Acc: 0.8511 | LR: 0.000886 | Time: 11.7s
# Epoch [185/200] | Train Loss: 0.0116 | Train Acc: 0.9977 | Val Loss: 0.6733 | Val Acc: 0.8419 | LR: 0.000785 | Time: 11.8s
# Epoch [186/200] | Train Loss: 0.0143 | Train Acc: 0.9955 | Val Loss: 0.6887 | Val Acc: 0.8498 | LR: 0.000691 | Time: 11.6s
# Epoch [187/200] | Train Loss: 0.0164 | Train Acc: 0.9955 | Val Loss: 0.6441 | Val Acc: 0.8551 | LR: 0.000602 | Time: 11.5s
# Epoch [188/200] | Train Loss: 0.0098 | Train Acc: 0.9977 | Val Loss: 0.6600 | Val Acc: 0.8472 | LR: 0.000519 | Time: 11.6s
# Epoch [189/200] | Train Loss: 0.0122 | Train Acc: 0.9966 | Val Loss: 0.6568 | Val Acc: 0.8472 | LR: 0.000443 | Time: 11.7s
# Epoch [190/200] | Train Loss: 0.0131 | Train Acc: 0.9966 | Val Loss: 0.6554 | Val Acc: 0.8445 | LR: 0.000372 | Time: 11.7s
# Epoch [191/200] | Train Loss: 0.0115 | Train Acc: 0.9983 | Val Loss: 0.6457 | Val Acc: 0.8498 | LR: 0.000308 | Time: 11.6s
# Epoch [192/200] | Train Loss: 0.0086 | Train Acc: 0.9983 | Val Loss: 0.6757 | Val Acc: 0.8524 | LR: 0.000249 | Time: 11.7s
# Epoch [193/200] | Train Loss: 0.0104 | Train Acc: 0.9977 | Val Loss: 0.6672 | Val Acc: 0.8485 | LR: 0.000197 | Time: 11.6s
# Epoch [194/200] | Train Loss: 0.0159 | Train Acc: 0.9955 | Val Loss: 0.6477 | Val Acc: 0.8498 | LR: 0.000151 | Time: 11.6s
# Epoch [195/200] | Train Loss: 0.0119 | Train Acc: 0.9966 | Val Loss: 0.6650 | Val Acc: 0.8472 | LR: 0.000111 | Time: 11.6s
# Epoch [196/200] | Train Loss: 0.0122 | Train Acc: 0.9977 | Val Loss: 0.6567 | Val Acc: 0.8511 | LR: 0.000077 | Time: 11.6s
# Epoch [197/200] | Train Loss: 0.0156 | Train Acc: 0.9955 | Val Loss: 0.6701 | Val Acc: 0.8472 | LR: 0.000049 | Time: 11.7s
# Epoch [198/200] | Train Loss: 0.0115 | Train Acc: 0.9977 | Val Loss: 0.6583 | Val Acc: 0.8485 | LR: 0.000028 | Time: 11.6s
# Epoch [199/200] | Train Loss: 0.0119 | Train Acc: 0.9960 | Val Loss: 0.6492 | Val Acc: 0.8524 | LR: 0.000012 | Time: 11.6s
# Epoch [200/200] | Train Loss: 0.0105 | Train Acc: 0.9966 | Val Loss: 0.6622 | Val Acc: 0.8472 | LR: 0.000003 | Time: 11.6s
#
# ============================================================================
# Experiment complete
# ============================================================================
# Best validation accuracy : 0.8630 (86.30%)
# Best epoch               : 175
# Total time               : 39.4 minutes
# Delta vs local 100e-bs8  : +1.06 pp
# Delta vs paper baseline  : -3.70 pp
# Checkpoint               : /kaggle/working/focus_rcnet_baseline_ce_e200_bs16_best.pth
# History CSV              : /kaggle/working/training_history_focus_rcnet_baseline_ce_e200_bs16.csv
# Summary CSV              : /kaggle/working/summary_focus_rcnet_baseline_ce_e200_bs16.csv
# Training curves          : /kaggle/working/training_curves_focus_rcnet_baseline_ce_e200_bs16.png
# ============================================================================
